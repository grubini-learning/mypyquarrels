# %%
class Graph:
    def __init__(self, vertices):
        self.vertices = vertices
        self.directions = {vertex: set() for vertex in range(vertices + 1)}
        self.seen = set()
        self.topological_sort = []
        self.stack = []

    def add_edge(self, nodea, nodeb):
        self.directions[nodea].add(nodeb)

    def get_graph(self):
        return self.directions

    def get_topological_sort(self):
        return self.topological_sort

    def get_seen(self):
        return self.seen

    def validation(self):
        groups = []
        for key in range(1, self.vertices + 1):
            if key not in self.seen:
                self.dfs_traversal(key)
                groups.append(self.seen)
            if self.check_consecutive() and len(self.topological_sort) == self.vertices:
                #print('=================================')
                return 1
            #print('=================================')
            self.topological_sort.clear()
            self.seen.clear()
        return groups

    def dfs_traversal(self, node):
        self.seen.add(node)
        #print(node)
        print(f'neighbors {self.directions[node]}')
        for neighbor in self.directions[node]:
            if neighbor not in self.seen:
                self.dfs_traversal(neighbor)
        self.topological_sort.insert(0, node)

    def check_consecutive(self):
        for i in range(len(self.topological_sort) - 1):
            if self.topological_sort[i + 1] not in self.directions[self.topological_sort[i]]:
                return False
            #print(self.topological_sort)
        return True

# %%
with open("rosalind_sc.txt", "r") as f:
    graphs = int(f.readline().strip())
    f.readline()
    result = []

    for graph in range(graphs):
        vertices, edges = map(int, f.readline().split(" "))
        g = Graph(vertices)
        #dag = {i : set([]) for i in range(vertices + 1)}
        #sink = False
        while True:
            line = f.readline()
            if line == '\n' or not line:
                break
            nodea, nodeb = map(int, line.split())
            g.add_edge(nodea, nodeb)
        result.append(g.validation())

with open("result.txt", "w") as f:
    for item in result:
        f.write(str(item))
        f.write(" ")
# Out:
#  {528, 752, 691, 183}
# neighbors {480, 659, 612, 687}
# neighbors {742, 267, 238, 687, 720, 560, 151, 311, 414}
# neighbors {515, 805, 167, 618, 88, 793, 474, 476}
# neighbors {452, 781, 439, 153, 413}
# neighbors {288, 35, 267, 334, 509}
# neighbors {711, 459, 558, 19, 349, 63}
# neighbors {450, 611, 771, 71, 371, 437, 733}
# neighbors {154, 150}
# neighbors {606, 595, 475, 254, 635, 510}
# neighbors {578, 162, 392, 713, 141, 629, 565, 91}
# neighbors {33, 34, 519, 328, 201, 106, 489, 22, 94, 604, 318}
# neighbors {709, 778, 587, 462, 14, 755, 153, 250, 31}
# neighbors {291, 581, 294, 521, 627, 149}
# neighbors {65, 276, 134}
# neighbors {739, 479}
# neighbors {49, 156, 375}
# neighbors {612, 550, 653, 526, 20, 469}
# neighbors {200, 477, 128}
# neighbors {168, 418, 518}
# neighbors {391, 103, 743, 716, 205, 337, 146, 209, 543}
# neighbors {81, 34, 637, 463}
# neighbors {136, 110, 566, 295}
# neighbors {162, 263, 240, 505, 26, 347, 126}
# neighbors set()
# neighbors {113, 450, 539, 793}
# neighbors {291, 122, 443, 127}
# neighbors {321, 530, 713, 261}
# neighbors {449, 42, 708, 229}
# neighbors {585, 665, 527}
# neighbors {134, 72, 491, 333, 602, 445}
# neighbors {768, 674, 72, 40, 94}
# neighbors {384, 326, 179, 532, 628, 791, 795, 734}
# neighbors {545, 362, 331, 141, 269, 595, 663, 91, 126}
# neighbors {477, 805, 38, 359, 169, 778, 300, 560, 792, 28, 349, 766}
# neighbors {131, 324, 486, 460, 376, 221}
# neighbors {224, 482, 74, 559, 207}
# neighbors {385, 327, 428, 624, 316, 733}
# neighbors {642, 553, 331, 428, 108, 206, 304, 370, 244, 438}
# neighbors {230, 555, 338, 538, 22, 440, 346, 478}
# neighbors {450, 738, 743, 360, 757, 634, 636}
# neighbors {547, 229, 294, 621, 557, 756, 158}
# neighbors set()
# neighbors {390, 488, 744, 464, 83, 442, 315, 349}
# neighbors {480, 645, 555, 300, 436, 470, 89, 92, 766, 575}
# neighbors {91, 747}
# neighbors {1, 66, 585, 42, 298, 108, 703}
# neighbors {4, 752, 307, 568, 669, 223}
# neighbors {288, 132, 804, 399, 339, 469, 253}
# neighbors {576, 330, 709}
# neighbors {604, 764}
# neighbors {672, 73, 746, 439}
# neighbors {282, 773, 510}
# neighbors {32, 651}
# neighbors {352, 66, 583, 269, 238, 759, 765}
# neighbors set()
# neighbors {664, 633, 114, 12}
# neighbors {353, 8, 780, 142, 219, 318}
# neighbors {578, 674, 773, 169, 746, 459, 745, 430, 722, 724, 791, 792, 571, 253, 446}
# neighbors {33, 754}
# neighbors {412, 274, 428, 489}
# neighbors {640, 673, 290, 355, 197, 232, 286}
# neighbors {352, 256, 548, 105, 138, 785, 793, 572, 285, 414}
# neighbors {430, 622}
# neighbors {226, 450, 484, 169, 433, 22, 408}
# neighbors {56, 683, 300, 149}
# neighbors {67, 485, 713, 556, 278}
# neighbors {288, 385, 644, 456, 427, 525, 110, 116, 724, 474, 765, 63}
# neighbors {602}
# neighbors {208, 226, 119}
# neighbors {66, 70, 395, 396, 568, 473, 58, 219}
# neighbors {738, 643, 418, 328, 722}
# neighbors {521, 554, 225, 503}
# neighbors {292, 100, 556, 143, 84, 244, 118, 251}
# neighbors {672, 10, 205, 208, 625, 567, 409, 701}
# neighbors {736, 197, 361, 463, 240, 112, 502, 699}
# neighbors {289, 365, 239, 118, 153, 671}
# neighbors {227, 422, 200, 403, 287}
# neighbors {682, 558, 494, 655, 156, 242, 279, 92}
# neighbors {73, 666, 205}
# neighbors {456, 49, 535, 375}
# neighbors {2, 72, 251, 216, 795, 413}
# neighbors {280, 594, 220}
# neighbors {434, 107, 790}
# neighbors {68, 267, 688, 309, 188}
# neighbors {289, 610, 520, 521, 301, 142, 368, 530, 275, 500}
# neighbors {36, 169, 433, 563, 55, 89, 219}
# neighbors {105, 267, 590, 49, 378}
# neighbors {298, 308, 326, 230}
# neighbors {97, 515, 36, 428, 332, 505, 474}
# neighbors {435, 526, 591, 359}
# neighbors {544, 548, 5, 553, 558, 78, 688, 756, 281, 186, 509}
# neighbors {609, 643, 745, 489, 15, 82, 725, 605}
# neighbors {301, 251, 333}
# neighbors {490, 169, 306, 403}
# neighbors {320, 33, 704, 482, 674, 549, 628, 23, 569}
# neighbors {281, 194, 12}
# neighbors set()
# neighbors {282, 803, 493}
# neighbors {20, 255}
# neighbors {68, 584, 651, 492, 90, 797}
# neighbors {704, 290, 515, 388, 648, 111, 592, 81, 626, 151, 665, 447}
# neighbors {706, 771, 405, 279, 763}
# neighbors {242, 757, 590, 343}
# neighbors {353, 423, 495, 692, 695}
# neighbors {419, 100, 196, 778, 561, 598, 216, 60, 317}
# neighbors {288, 194, 71, 560, 242, 312}
# neighbors {128, 513, 489, 74, 395, 266, 331, 432, 243, 727, 635}
# neighbors {265, 752, 245, 252, 190}
# neighbors {209, 788, 532}
# neighbors {248, 774}
# neighbors {450, 613, 585, 597, 183, 634, 667, 375}
# neighbors {481, 7, 654, 366, 176, 535, 251}
# neighbors {228, 517, 519, 782, 474}
# neighbors {198, 105, 719, 721, 408, 797}
# neighbors {592, 120, 492}
# neighbors {385, 235, 332, 391}
# neighbors {353, 68, 199, 528, 465, 272, 83, 565, 696, 602}
# neighbors {737}
# neighbors {169, 685, 215}
# neighbors {743, 136, 777, 112, 60}
# neighbors {705, 235, 750, 793, 191}
# neighbors {457, 186}
# neighbors {40, 36, 93}
# neighbors {257, 418, 452, 295, 79, 599}
# neighbors {325, 718, 592, 434, 662, 571}
# neighbors {96, 576, 491, 334, 304, 443, 284}
# neighbors {452, 773, 265, 272, 561, 500, 758, 472}
# neighbors {16, 337, 409, 203}
# neighbors {205, 175}
# neighbors {386, 130, 5, 37, 723, 789, 541}
# neighbors {232, 201, 778, 497, 179, 31}
# neighbors {774, 533, 249, 572, 317, 159}
# neighbors {712, 130}
# neighbors {320, 516, 427, 269, 240, 148}
# neighbors {417, 193, 301, 623, 691, 661, 184}
# neighbors {257, 579, 38, 437, 475, 798}
# neighbors {539, 253, 342}
# neighbors {356, 371, 25, 188, 159}
# neighbors {207, 594, 148, 308, 24}
# neighbors {642, 267, 180}
# neighbors {768, 806, 683, 783, 116, 149}
# neighbors {736, 448, 631, 744, 59, 264, 457, 791, 603, 348}
# neighbors {803, 326, 427, 332, 628, 92}
# neighbors {245, 214, 709, 550}
# neighbors {801, 69, 614, 798, 560, 664, 285, 414}
# neighbors {713, 394, 204, 207, 280, 155}
# neighbors {385, 175, 752, 21, 473}
# neighbors {483, 293, 630, 246, 378, 123, 254}
# neighbors {100, 501}
# neighbors {355, 653, 695, 281, 154}
# neighbors {480, 732, 4, 454, 262, 238, 527, 366, 726, 94, 665, 764, 798}
# neighbors {289, 738, 420, 78, 143, 432, 278, 122, 637}
# neighbors {611, 678, 617, 141, 302, 153}
# neighbors {197, 440, 108, 78, 245, 568, 798}
# neighbors {322, 645, 663, 568, 315}
# neighbors {162, 196, 171, 464, 89, 154}
# neighbors {385, 675, 597, 303}
# neighbors {480, 321, 36, 102, 73, 180, 437, 404, 695, 602}
# neighbors {658, 523, 6}
# neighbors {612, 332, 656, 788, 598, 88}
# neighbors {806, 619, 45, 495, 690, 84, 789, 438, 535, 505}
# neighbors {260, 198, 456, 113, 277, 312, 764}
# neighbors {80, 257, 83, 356}
# neighbors {449, 196, 201, 493, 191}
# neighbors {199, 524, 718, 558, 756, 501, 90}
# neighbors {692, 670}
# neighbors {545, 642, 676, 229, 440, 552, 269, 17, 148, 55, 728}
# neighbors {704, 388, 612, 655, 50, 596, 447}
# neighbors {64, 769, 518, 390, 589, 500, 568}
# neighbors {649, 565, 294, 486}
# neighbors {292, 103, 496, 665, 339, 150, 729}
# neighbors {72, 426, 461, 753, 497, 437, 54}
# neighbors {521, 432, 242, 755, 535, 767}
# neighbors {530, 806, 31}
# neighbors {776, 267, 780, 334, 22, 471, 222}
# neighbors {548, 454, 198, 663, 188}
# neighbors {192, 546, 195, 782, 526, 435, 564, 91, 317}
# neighbors {706, 203, 787, 470, 90, 318, 63}
# neighbors {201, 553, 479, 49, 18, 628, 760, 253, 349, 671}
# neighbors {513, 422, 326, 550, 721, 189, 574}
# neighbors {226, 771, 708, 613, 78, 435, 629}
# neighbors {490, 759, 213, 375, 121}
# neighbors {553, 74, 205, 503}
# neighbors {33, 573, 649, 106, 61}
# neighbors {610, 99, 164, 373, 602, 254}
# neighbors {218, 439}
# neighbors {481, 391, 464, 437, 28, 253}
# neighbors {492, 334, 80, 253, 315, 637}
# neighbors {265, 740}
# neighbors {140, 429, 209, 17, 438}
# neighbors {676, 565, 199}
# neighbors {421, 139, 301, 501, 762, 286}
# neighbors {626, 21, 478, 742}
# neighbors {194, 348, 725, 55}
# neighbors {486, 582, 617, 522, 655, 369, 147}
# neighbors {573, 804, 774, 342, 250, 61, 223}
# neighbors {602, 188, 293, 206}
# neighbors {264, 552, 77, 176, 177, 502, 507, 379, 671}
# neighbors {514, 708, 299, 684, 368, 272, 498, 282, 443, 254}
# neighbors {805, 8, 138, 24, 123}
# neighbors {777, 554, 619, 80, 28}
# neighbors {1, 428, 141, 399, 542}
# neighbors {193, 388, 138, 560, 342, 285, 94, 767}
# neighbors {358, 172, 400, 603, 92}
# neighbors {600, 689, 22, 25}
# neighbors {353, 114, 23, 541, 414}
# neighbors {781, 239, 173, 511}
# neighbors {668, 387, 132, 247, 444, 703}
# neighbors {419, 613, 712, 177, 54, 474, 412, 766}
# neighbors {3, 199, 456, 494, 18, 150}
# neighbors {140, 426, 778, 508}
# neighbors {96, 3, 5, 493, 782, 241, 434, 757, 568, 697, 347, 798}
# neighbors {481, 449, 40, 496, 497, 89, 605, 413}
# neighbors {268, 61, 123, 604, 317, 63}
# neighbors {212, 262, 470, 583}
# neighbors {5, 714, 143, 498, 280}
# neighbors {256, 729, 426, 678}
# neighbors {485, 75, 462, 23, 478, 543}
# neighbors {164, 783, 145, 118, 503, 283, 63}
# neighbors {544, 66, 493, 463, 82, 151}
# neighbors {33, 551, 359, 530, 532, 23, 567}
# neighbors {224, 677, 103}
# neighbors {443, 645, 695}
# neighbors {96, 128, 169, 250, 378, 656, 730}
# neighbors {303}
# neighbors {378, 292}
# neighbors {675, 359, 459, 621, 591, 657, 761, 667}
# neighbors {388, 563, 532, 5}
# neighbors {74, 419, 678}
# neighbors {96, 68, 177, 146, 179, 470}
# neighbors {225, 648, 584, 782, 15, 275, 85, 442, 158}
# neighbors {548, 325, 38, 104, 494, 308}
# neighbors {430, 372, 565, 535, 505}
# neighbors {771, 646, 486, 712, 298, 140, 398, 560, 185, 762}
# neighbors {610, 708, 316}
# neighbors {290, 523, 716, 785, 50, 113, 625, 502, 791, 605, 510}
# neighbors {610, 37, 165, 40, 721, 83, 278, 184}
# neighbors set()
# neighbors {35, 484, 106, 594, 93}
# neighbors {642, 420, 613, 38, 654, 52, 409}
# neighbors {320, 196, 270, 562, 726, 440}
# neighbors {682, 524, 15, 595, 308}
# neighbors {224, 746, 427, 628, 788, 315}
# neighbors {592, 729, 130, 783}
# neighbors {674, 356, 135, 718, 80, 598}
# neighbors {34, 329, 176, 723, 766}
# neighbors {163}
# neighbors {568, 199, 76, 367}
# neighbors {712, 43, 332, 623, 784, 310, 375, 795}
# neighbors {482, 260, 557, 46, 302, 179, 697}
# neighbors {232, 342, 687}
# neighbors {643, 105, 684, 590, 765}
# neighbors {801, 609, 450, 386, 112, 468, 22, 378}
# neighbors {433, 491, 44, 405}
# neighbors {196, 420, 647, 331, 491, 206, 303, 403, 249, 671}
# neighbors {796, 78}
# neighbors {105, 430, 431, 474, 730, 348, 351}
# neighbors {212, 751}
# neighbors {291, 453, 103, 616, 557, 559, 242, 312}
# neighbors {680, 451, 279, 251}
# neighbors {784, 81, 497, 83, 404}
# neighbors {352, 482, 644, 742, 657}
# neighbors {705, 610, 711, 459, 668}
# neighbors {676, 777, 234, 619, 591, 16, 798, 626, 276, 606}
# neighbors {417, 293, 713, 79, 441, 730}
# neighbors {225, 323, 170, 592, 22, 376}
# neighbors {640, 690, 404, 699, 479}
# neighbors {32, 449, 581, 750}
# neighbors {513, 612, 335, 784, 627, 150, 607}
# neighbors {549, 328, 175, 528, 212, 532, 246, 280, 27, 510}
# neighbors {128, 616, 361, 489, 470}
# neighbors {773, 712, 619, 717, 146, 660, 90, 59}
# neighbors {736, 210, 316, 205}
# neighbors {771, 69, 363, 655, 47, 211, 276, 599, 443, 445}
# neighbors {206, 240, 497, 178, 788, 471, 315}
# neighbors {320, 197, 645, 623, 85}
# neighbors {8, 761, 395, 103}
# neighbors {262, 137, 301, 279, 157}
# neighbors {775, 242, 118, 151, 95}
# neighbors {7, 392, 10, 790, 663}
# neighbors {808, 433, 234}
# neighbors {192, 460, 629}
# neighbors {194, 26, 617, 107, 207, 243, 499, 442}
# neighbors {228, 646, 390, 236, 462, 19, 375, 475, 636, 605}
# neighbors {514, 582, 199, 107, 400, 562, 149, 663, 601, 477, 254}
# neighbors {549, 391, 553, 663, 158, 703}
# neighbors {608, 65, 549, 108, 110, 252}
# neighbors {328, 651, 598, 55, 216, 92, 30}
# neighbors {288, 32, 803, 484, 773, 133, 48, 530, 658, 796, 287}
# neighbors {803, 617, 562, 307, 85, 695}
# neighbors {130, 652, 721, 441, 284}
# neighbors {648, 171, 743}
# neighbors {739, 199, 264, 234, 209, 306, 758}
# neighbors {418, 239}
# neighbors {772, 233, 43, 439, 510}
# neighbors {400, 25, 483}
# neighbors {196, 682, 652, 653, 242, 55}
# neighbors {274, 628, 358}
# neighbors {674, 166, 45, 22, 796, 382}
# neighbors {792, 264, 283, 9}
# neighbors {712, 771, 88, 796}
# neighbors {562, 220, 244, 799}
# neighbors {18, 469, 614}
# neighbors {416, 258, 497, 247, 443, 158}
# neighbors {581, 775, 42, 395, 494, 753, 594, 281, 318}
# neighbors {773, 497, 401, 310, 761, 573, 670}
# neighbors {512, 689, 57, 58, 349, 222}
# neighbors {646, 39, 461, 432, 152, 378, 542}
# neighbors {65, 611, 198, 584, 394, 363, 334, 753, 179, 476}
# neighbors {356, 230, 716, 751, 527, 48, 51, 255}
# neighbors {740, 329, 589, 782, 151, 59}
# neighbors {626, 299, 298}
# neighbors {705, 226, 292, 553, 82, 20, 407}
# neighbors {714, 210, 723, 87}
# neighbors {735, 14, 63}
# neighbors {288, 40, 808, 107, 144, 368, 532, 798}
# neighbors {577, 777}
# neighbors {64, 672, 195, 227, 683, 300, 19, 217}
# neighbors {546, 131, 452, 645, 44, 142, 270, 798}
# neighbors {480, 2, 559, 696, 633, 731, 669}
# neighbors {674, 610, 616, 360, 618, 201, 783, 178, 789, 56, 634}
# neighbors {160, 132, 234, 331, 145, 213, 151, 732, 477}
# neighbors {738, 649, 586, 402, 628, 151, 442}
# neighbors {737, 259, 46, 431, 367}
# neighbors {355, 37, 199, 423, 656, 80, 404, 533}
# neighbors {578, 491, 209, 530, 631}
# neighbors {150, 506, 258, 618}
# neighbors {800, 281, 464}
# neighbors {802, 131, 757, 309, 314}
# neighbors {737, 112, 593, 274, 635, 733}
# neighbors {290, 430, 753, 216, 381, 639}
# neighbors {248, 409, 428, 6}
# neighbors {265, 492, 723, 436, 509}
# neighbors {606, 546, 702}
# neighbors {492, 305, 210, 563, 177, 346, 317}
# neighbors {280, 619, 286, 695}
# neighbors {360, 795, 124, 423}
# neighbors {83, 531, 756, 390}
# neighbors {96, 33, 581, 489, 649, 238, 538, 666, 476, 254}
# neighbors {740, 429, 79, 722, 246}
# neighbors {424, 657, 207, 271}
# neighbors {105, 236, 563, 180, 246, 409, 187, 381}
# neighbors {768, 370, 306, 600, 58}
# neighbors {97, 206, 145, 497, 467, 595, 662, 408, 574, 191}
# neighbors {644, 774, 459, 749, 371, 412, 253}
# neighbors {350, 427, 47, 368, 657, 530, 533, 409, 475, 254, 95}
# neighbors {744, 523, 771, 367}
# neighbors {699, 251}
# neighbors {120, 570, 556}
# neighbors {321, 66, 278, 799}
# neighbors {574, 298, 11, 115, 283, 734}
# neighbors {192, 738, 774, 79, 112, 690, 372, 213, 246, 797}
# neighbors {518, 219, 124, 53, 182, 283, 732}
# neighbors {515, 387, 294, 489, 463, 335}
# neighbors {641, 648, 779, 684, 753, 370, 531, 184, 636, 639}
# neighbors {581, 360, 523, 235, 720, 690}
# neighbors {382, 70}
# neighbors {385, 741, 807, 109, 784, 787, 500, 62}
# neighbors {485, 295, 778, 426, 333, 752, 369, 432, 92, 93}
# neighbors {289}
# neighbors {736, 801, 555, 173, 734}
# neighbors {178, 217, 153}
# neighbors {649, 490, 174, 630, 697}
# neighbors {369, 596, 734, 556}
# neighbors {709, 491, 308, 727, 444}
# neighbors {259}
# neighbors {544, 389, 654, 340, 251, 510}
# neighbors {550, 525, 336, 656, 658, 82, 379, 447}
# neighbors {145, 555, 217, 271}
# neighbors {263, 266, 75, 234, 17, 380}
# neighbors {473, 2, 435, 511}
# neighbors {640, 325, 235, 268, 589, 174, 430, 428, 332, 181}
# neighbors {227, 197, 38, 591, 693, 795, 124}
# neighbors {608, 520, 367, 244, 664}
# neighbors {768, 41, 11, 13}
# neighbors {227, 739, 453, 174, 92}
# neighbors {802, 455, 426, 74, 266, 530, 281}
# neighbors {480, 403, 605, 680}
# neighbors {399, 267, 367, 227}
# neighbors {257, 441, 76, 413}
# neighbors {485, 584, 8, 656, 84, 634}
# neighbors {229, 453, 586, 47, 369, 757, 282, 510, 31}
# neighbors {784, 76, 717, 416}
# neighbors {801, 706, 674, 178, 575}
# neighbors {787}
# neighbors {577, 3, 318}
# neighbors {481, 482}
# neighbors {544, 533, 311}
# neighbors {696, 561, 277, 774}
# neighbors {550, 232, 629, 666, 638}
# neighbors {448, 491, 563, 789, 315, 604}
# neighbors {355, 11, 91, 756}
# neighbors {362, 291, 340}
# neighbors {169, 398, 179, 54, 278, 475, 798}
# neighbors {448, 618, 316, 349}
# neighbors {355, 525, 754, 371, 637}
# neighbors {194, 588, 688, 791, 24, 185, 637, 318}
# neighbors {96, 164, 709, 170, 682, 599, 158}
# neighbors {771, 17, 50, 212, 634, 349}
# neighbors {425, 634, 284, 22}
# neighbors {130, 362, 111, 496, 412, 59, 476, 766}
# neighbors {234, 396, 495, 725, 183, 25, 507, 412}
# neighbors {448, 355, 804, 134, 297, 458, 439}
# neighbors {480, 134, 7, 682, 298, 619, 697, 154}
# neighbors {672, 192, 303, 304, 181, 600, 761, 445}
# neighbors {490, 112, 115, 23, 184, 313, 157}
# neighbors {763, 516, 366}
# neighbors {634, 699}
# neighbors {192, 449, 33, 200, 603}
# neighbors {83}
# neighbors {299, 155, 397}
# neighbors {536, 433, 595, 94}
# neighbors {704, 497, 781, 792}
# neighbors {512, 33, 164, 489, 176}
# neighbors {710, 135, 265, 433, 214, 760, 222}
# neighbors {734, 237, 21, 475, 156, 126}
# neighbors {65, 644, 744, 298, 332, 498, 94}
# neighbors {705, 265, 524, 270, 54, 575}
# neighbors {320, 360, 107, 331, 76, 12, 151, 315}
# neighbors {641, 101, 211, 632, 537, 348, 734}
# neighbors {770, 613, 430, 496, 560, 243, 83}
# neighbors {559, 466, 277, 662, 567, 598, 121}
# neighbors {674, 196, 233, 752, 725, 440}
# neighbors {522, 398, 143, 273, 498, 145, 276, 569}
# neighbors {197, 648, 713, 746, 186, 141, 502, 23, 346, 315}
# neighbors {547, 516, 229, 586, 268, 239, 623, 793}
# neighbors {338, 531, 44, 109}
# neighbors {800, 674, 710, 585, 330, 716, 588, 569, 118, 729, 575}
# neighbors {384, 513, 258, 163, 36, 581, 488, 15, 145, 633, 698}
# neighbors {640, 292, 709, 139, 363, 109, 141, 619, 629, 310, 26, 510}
# neighbors {672, 10, 205, 208, 625, 567, 409, 701}
# neighbors {352, 9, 700, 404}
# neighbors {481, 267, 717, 205, 47, 698, 30}
# neighbors {690, 253, 718}
# neighbors {96, 609, 452, 325, 804, 309}
# neighbors {225, 579, 103, 104, 431, 144, 307}
# neighbors {250, 242, 642, 535}
# neighbors {428, 604}
# neighbors {462, 499, 216, 378, 61, 478}
# neighbors {173, 144, 691, 726, 26}
# neighbors {139, 36}
# neighbors {774, 713, 497, 371, 92}
# neighbors {520, 562}
# neighbors {80, 754, 438, 176}
# neighbors {213, 504, 802, 621}
# neighbors {195, 613, 297, 527, 85, 791, 184, 93}
# neighbors {780, 561, 403, 634, 763}
# neighbors {409, 186, 755, 52}
# neighbors {754}
# neighbors {58, 92, 78}
# neighbors {56, 154, 741}
# neighbors {394, 780, 368, 562, 215, 728, 478}
# neighbors {449, 740, 454, 295, 336, 440}
# neighbors {578, 309, 565, 376, 409, 381, 445}
# neighbors {613, 137, 333, 346, 720, 570, 408, 282, 88}
# neighbors {323, 268, 175, 437, 214, 504}
# neighbors {195, 776, 553, 205, 496, 30, 569, 698, 730}
# neighbors {644, 551, 302, 751, 147, 212, 151, 600, 345, 603, 220}
# neighbors {177, 147, 324}
# neighbors {193, 578, 450, 553, 335, 791, 536, 698}
# neighbors {576, 202, 717, 207, 335, 595, 437}
# neighbors {803, 750, 21, 149, 759, 476}
# neighbors {100, 385, 450, 524}
# neighbors {166, 431, 51, 565, 86, 597}
# neighbors {326, 778, 555, 274, 694, 55, 761}
# neighbors {586, 266, 565}
# neighbors {743, 300, 591, 341, 24, 729, 314, 93}
# neighbors {513, 769, 579, 739, 774, 695}
# neighbors {376, 466, 160, 807}
# neighbors {1, 385, 678, 522, 652, 462, 596, 628, 214, 317}
# neighbors {645, 682, 559, 178, 755}
# neighbors {57, 779, 60}
# neighbors {152, 691}
# neighbors {332, 367, 120, 90, 541}
# neighbors {612, 100, 423, 144, 475}
# neighbors {611, 457, 76, 593, 754}
# neighbors {769, 452, 458, 589, 758, 122}
# neighbors {635, 454, 246}
# neighbors {801, 740, 5, 43, 90, 603}
# neighbors {771, 35, 137, 659, 247, 89, 602, 124, 190}
# neighbors {162, 738, 130, 482, 487, 327, 775, 543}
# neighbors {713, 650, 502, 123, 61}
# neighbors {550, 51, 581, 462}
# neighbors {192, 544, 657, 83, 541}
# neighbors {194, 70, 391, 583, 314, 478, 191}
# neighbors {665, 340, 750}
# neighbors {192, 257, 707, 268, 366, 145, 113, 697, 701, 31}
# neighbors {594, 475, 322, 634}
# neighbors {727, 784, 465, 149, 598, 759}
# neighbors {649, 804}
# neighbors {497, 322, 558}
# neighbors {161, 516, 519, 49, 725}
# neighbors {800, 32, 290, 387, 6, 710, 712, 432, 625}
# neighbors {65, 587, 108, 433, 507}
# neighbors {34, 699, 44}
# neighbors {449, 549, 718, 92, 434, 20, 761, 540}
# neighbors {752, 291}
# neighbors {672, 718, 751, 52, 345}
# neighbors {808, 729, 696}
# neighbors {193, 169, 651, 720, 789, 377, 411, 316, 95}
# neighbors {128, 260, 31}
# neighbors {581, 328, 498, 309, 155}
# neighbors {520, 205, 109}
# neighbors {193, 354, 458, 43, 436, 696, 797, 510}
# neighbors {113, 652, 551}
# neighbors {549, 137, 619, 364, 241, 498, 28, 413, 606}
# neighbors {579, 165, 678, 40, 686, 207, 176, 149, 56}
# neighbors {582, 393, 394, 313, 122, 413, 191}
# neighbors {206, 51, 595, 340, 573}
# neighbors {737, 389, 390, 6, 428, 399, 527, 239, 280, 601}
# neighbors {323, 230, 231, 81, 722, 689, 473, 58, 318, 735}
# neighbors {8, 747, 46, 241, 212, 637}
# neighbors {448, 773, 454, 296, 138, 435, 564, 89}
# neighbors {201}
# neighbors {392, 395, 651, 46, 14, 532, 341, 182, 667}
# neighbors {3, 675, 275, 253, 414}
# neighbors {803, 718, 658, 724, 470, 278}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-03b7ed00296b> in <module>
#      15             nodea, nodeb = map(int, line.split())
#      16             g.add_edge(nodea, nodeb)
# ---> 17         result.append(g.validation())
#      18
#      19 with open("result.txt", "w") as f:
#
# <ipython-input-42-bf89b7cf7deb> in validation(self)
#      23         for key in range(1, self.vertices + 1):
#      24             if key not in self.seen:
# ---> 25                 self.dfs_traversal(key)
#      26                 groups.append(self.seen)
#      27             if self.check_consecutive() and len(self.topological_sort) == self.vertices:
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
# ---> 41                 self.dfs_traversal(neighbor)
#      42         self.topological_sort.insert(0, node)
#      43
#
# <ipython-input-42-bf89b7cf7deb> in dfs_traversal(self, node)
#      36         self.seen.add(node)
#      37         #print(node)
# ---> 38         print(f'neighbors {self.directions[node]}')
#      39         for neighbor in self.directions[node]:
#      40             if neighbor not in self.seen:
#
# ~/Library/Python/3.8/lib/python/site-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/Library/Python/3.8/lib/python/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/Library/Python/3.8/lib/python/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/Library/Python/3.8/lib/python/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
